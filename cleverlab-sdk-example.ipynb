# %%
from cleverlab import Cleverlab
cleverGuy = Cleverlab("test", "cleverlab")

cleverGuy.getTemperature()
# Out:
# logged in
# Temerature: 25.5
# Humidity: 52.0
# AirPressure: 961.6400146484375

# %%
cleverGuy.addNote("this is a test note")
cleverGuy.getNoteList()
# Out:
# New note ID: 48
# [Id: 48
# Timestamp: 1567761975494
# Content: "das ist eine Testnotiz"
# , Id: 47
# Timestamp: 1567761414301
# Content: "das ist eine Testnotiz"
# , Id: 46
# Timestamp: 1567760630806
# Content: "DAS IST EINE TESTNOTIZ"
# , Id: 45
# Timestamp: 1567760617773
# Content: "DAS IST EINE TESTNOTIZ"
# , Id: 44
# Timestamp: 1567607781966
# Content: "test from skill engine123"
# , Id: 43
# Timestamp: 1567607760000
# Content: "test from skill engine123"
# , Id: 42
# Timestamp: 1567607715819
# Content: "test from skill engine123"
# , Id: 41
# Timestamp: 1567607680930
# Content: "this is a new note 3"
# , Id: 40
# Timestamp: 1567607627268
# Content: "test from skill engine123"
# , Id: 39
# Timestamp: 1567607627255
# Content: "test from skill engine123"
# , Id: 38
# Timestamp: 1567607554031
# Content: "test from skill engine123"
# , Id: 37
# Timestamp: 1567607554021
# Content: "test from skill engine123"
# , Id: 36
# Timestamp: 1567607544826
# ...
